# %%
# a=34
# b=6
# while b!=0:
#     a,b=a,b%a
#     print(a)

# %%
def gcd(a:int,b:int):
    if not isinstance(a,int) and not isinstance(b,int):
        raise TypeError ("both input must be integer")
    if b==0:
        return a
    return gcd(b,a%b)
if __name__=="__main__":
    try:
        a=34
        b=45
        result=gcd(a,b)
        print(result)
    except Exception as e:
        print(e)
# Out:
# 1

# %%
decimal=12
binary=""
while decimal>0:
    remainder=decimal%2
    binary=str(remainder)+binary
    deciaml=decimal//2
print(binary
decimal=45
binary=""
while decimal>0:
    remainder=decimal%2
    binary=str(remainder)+binary
    decimal=decimal//2
print(binary)

# %%
def decimal_find(num:int):
    if not isinstance(num,int):
        raise TypeError("input must be integer")
    if num==0:
        return 0
    Binary=""
    while num>0:
        remain=num%2
        Binary=str(remain)+Binary
        num=num//2
    return Binary
if __name__=="__main__":
    try:
        num=12
        result=decimal_find(num)
        print(result)
    except Excception as e:
        print(e)
# Out:
# 1100

# %%
List_1=[12,23,34]
List_2=[12,67,45]
empty=[]
for item in List_1:
    if item  in List_2:
        empty.append(item)

# %%
empty
# Out:
# [12]

# %%
def
