# %%
class galaxy:
    holidays="saturday"
    def __init__(self,name,college,course):
        self.name=name
        self.college=college
        self.course=course
    def student_details(self):
        return f"details of {self.name} is {self.course}"
    @classmethod
    def change_holidays(cls,change_holidays):
        cls.holidays=change_holidays
    @classmethod
    def object_creator(cls,string):
        string_return=string.split("-")
        return cls(string_return[0],string_return[1],string_return[2])
    @staticmethod
    def greeting_printer(name_string):
        return f"hello good morning {name_string}"
    @property
    def my_new_method(self):
        return 59
rahul=galaxy.object_creator("rahul-sharda university-machine learning")

# %%
object_rohit=galaxy("rohit","sharda","python")

# %%
rahul.student_details
# Out:
# <bound method galaxy.student_details of <__main__.galaxy object at 0x0000016D99F3CEC0>>

# %%
# @classmethod
# def object_creator(cls,dict1):
#     first_arg=dict1["name"]
#     sec_arg=dict2["college"]
#     third_arg=dict3["course"]
#     return cls(first_arg,sec_arg,third_arg)
# rahul=galaxy.

# %%
sorted_list=[12,23,34,45,56,67,78]
target=78
low=0
high=len(sorted_list)-1
while low<=high:
    mid=(low+high)//2
    if sorted_list[mid]==target:
        print(mid)
        break
    elif target<sorted_list[mid]:
        high=mid-1
    else:
        low=mid+1
else:
    print(-1)
# Out:
# 6

# %%
from array import *
arr= array('i',[23,34,45,78,89])
val=arr.index(34)
print(val)
# Out:
# 1

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from numpy import *
val=linspace(10,20,5)
for x in val:
    print(x,end=" ")
# Out:
# 10.0 12.5 15.0 17.5 20.0

# %%
from numpy import *
val=arange(10,20,8)
for x in val:
    print(x,end=" ")
# Out:
# 10 18
