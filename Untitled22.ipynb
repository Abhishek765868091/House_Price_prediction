# %%
my_list=[67,23,45,12,10,69]
length=len(my_list)
for i in range(length):
    for j in range(0,length-i-1):
        if my_list[j]>my_list[j+1]:
            my_list[j],my_list[j+1]=my_list[j+1],my_list[j]
           
print(my_list)
# Out:
# [10, 12, 23, 45, 67, 69]

# %%
def bubble_sort(my_list:list):
    if not isinstance(my_list,list):
        raise TypeError("input must have in the list")
    length=len(my_list)
    for i in range(length):
        for j in range(0,length-i-1):
            if my_list[j]>my_list[j+1]:
                my_list[j],my_list[j+1]=my_list[j+1],my_list[j]
    return my_list
if __name__=="__main__":
    my_list=[45,67,89,23,10,30]
    try:
        result=bubble_sort(my_list)
        print(result)
    except TypeError as error:
        print(error)
    except Exception as e:
        print(e)
# Out:
# [10, 23, 30, 45, 67, 89]

# %%
def check_binary(s):
    for i in range(len(s)):
        if s[i]!="0" and s[i]!="1":
            return False
    return True

# %%
check_binary("101010")
# Out:
# True

# %%
48%12
# Out:
# 0

# %%
48%18
# Out:
# 12

# %%
text=" this \n is \t python  "
result=""
pre_space=False
for char in text.strip():
    if not char.isspace():
        result=result+char
        pre_space=False
    else:
        if pre_space==False:
            result=result+" "
            pre_space=True
print(result)
# Out:
# this is python

# %%
def nums_list(List:list):

# %%
def sum_num(num:list):
    target=35
    num_map={}
    for i ,nums in enumerate(num):
        #print(nums,i)
        compliment=target-nums
        #print(compliment)
        if compliment in num_map:
            return [num_map[compliment],i]
        else:
            num_map[nums]=i

# %%
sum_num([12,45,89,23])
# Out:
# 23
# -10
# -54
# 12
# [0, 3]

# %%
2%4
# Out:
# 2

# %%
def counter(n):
    cnt=0
    while n>0:
        cnt=cnt+1
        n=n//10
    return cnt

# %%
counter(5567)
# Out:
# 4

# %%
n=5567//10

# %%
text="1122"
char=""
for item in text:
        char=item+char
print(char)
# Out:
# 2211

# %%
char
# Out:
# 'rraahc'

# %%
power=12
base=2
result=1
for i in range(power):
  result=result*base
print(result)
# Out:
# 4096

# %%
2**12
# Out:
# 4096

# %%
101%10
# Out:
# 1

# %%
def num(n):
    rev=0
    while n>0:
        last=n%10
        rev=rev*10+last
        n=n//10
    return rev

# %%
num(349)
# Out:
# 943

# %%
n=234
rev=""
for num in str(n):
    rev=num+rev
rev=int(rev)
print(rev)
# Out:
# 432

# %%
num = 1122
rev = ""

for digit in str(num):
    rev = digit + rev

rev = int(rev)
print(rev)
# Out:
# 2211

# %%
n1=123
cont=0
while n1>0:
    digit=n1%10
    cont=cont+digit
    n1=n1//10
print(cont)
# Out:
# 6

# %%
List=[34,12,70,90,45]
length=len(List)
swap=0
for i in range(length):
    for j in range(0,length-i-1):
        #print(i,j)
        if List[j]>List[j+1]:
            List[j],List[j+1]=List[j+1],List[j]
            swap+=1
print(List,swap)
# Out:
# [12, 34, 45, 70, 90] 3 90

# %%
List_1=[34,12,70,90,45]
length=len(List_1)
swap=0
for i in range(length):
    current_num=List_1[i]
    for j in range(i-1,-1,-1):
        #print(i,j,current_num)
        if List_1[j]>current_num:
            List_1[j],List_1[j+1]=List_1[j+1],List_1[j]
        else:
            List_1[j+1]=current_num
        swap+=1
print(List_1,swap)
# Out:
# 34
# 12
# 70
# 90
# 45
# [12, 45, 90, 90, 90] 10

# %%
List=[10,22,12,90]
target=100
num_map={}
for i,item in enumerate(List):
    comp=target-item
    if comp in num_map:
        print (num_map[comp],i)
    else:
        num_map[item]=i
# Out:
# 0 3

# %%
print(num_map)
# Out:
# {10: 0, 12: 2, 90: 3}

# %%
def sum_num(num:list):
    if not isinstance(num,list):
        raise TypeError("input must have in the list")
    target=35
    num_map={}
    for i ,nums in enumerate(num):
        #print(nums,i)
        compliment=target-nums
        #print(compliment)
        if compliment in num_map:
            return [num_map[compliment],i]
        else:
            num_map[nums]=i
if __name__=="__main__":
    num=[10,23,25,56,89]
    try:
        result=sum_num(num)
        print(result)
    except Exception as e:
        print(e)
# Out:
# [0, 2]

# %%
def amplify(number):
    
    if number>=1:
        List = []
        for i in range(1, number+1):

            List.append(i)

        for num in List:
            if num%4==0:

               List[List.index(num)]=num*10


            else:
                continue
     
    else:
        
        return "Number should be equal or greater than 1"
            
    return List  


print(amplify(4))
print(amplify(25))
print(amplify(0))
# Out:
# [1, 2, 3, 40]
# [1, 2, 3, 40, 5, 6, 7, 80, 9, 10, 11, 120, 13, 14, 15, 160, 17, 18, 19, 200, 21, 22, 23, 240, 25]
# Number should be equal or greater than 1

# %%
list2=[45,23,56,89,24,67]
length=len(list2)
swap=0
for i in range(length):
    for j in range(0,length-i-1):
        if list2[j]>list2[j+1]:
            list2[j],list2[j+1]=list2[j+1],list2[j]
            swap+=1
print(list2)
print(swap)
# Out:
# [23, 24, 45, 56, 67, 89] 5

# %%
text="programming"
dic={}
for char in text.replace(" ",""):
    if char  in dic:
        dic[char]+=1
    else:
        dic[char]=1
print(dic)
# Out:
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}

# %%
list1=[12,34,56,78,90]
list2=[34,45,67,89]
i=j=0
merge=[]
while i<len(list1) and j<len(list2):
    if list1[i]<=list2[j]:
        merge.append(list1[i])
        i+=1
    else:
        merge.append(list2[j])
        j+=1
while i<len(list1):
    merge.append(list1[i])
    i+=1
while j<len(list2):
    merge.append(list2[j])
    j+=1
print(merge)
# Out:
# [12, 34, 34, 45, 56, 67, 78, 89, 90]

# %%
# pow1=10
# base=-2
# result=1
# power=abs(base)
# for i in range(power):
#     result=result*base
# print(result)
# if base<0:
#     result=1/result
#     print(result)
# Out:
# 4
# 0.25

# %%
def power_count(x:float,n:int):
    result=1
    power=abs(n)
    for i in range(power):
        result=result*x
    # return result
    if n<0:
            return 1/result
    else:
      return result

# %%
power_count(2.00000,-2)
# Out:
# 0.25

# %%
abs(-3)
# Out:
# 3

# %%
for i in range(2,20,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
def ispalindrome(s:str):
    s="".join(char for char in s if char.isalnum())
    s=s.lower()
    rev_s=s[::-1]
    if s==rev_s:
        return True
    else:
        return False

# %%
ispalindrome("aca :aca")
# Out:
# True

# %%
n1=[12,23,56,78,89,90]
n2=[23,34,56,67,78]
m=[]
i=j=0
while i<len(n1) and j<len(n2):
    if n1[i]<=n2[j]:
        m.append(n1[i])
        i+=1
    else:
        m.append(n2[j])
        j+=1
while i<len(n1):
    m.append(n1[i])
    i+=1
while j<len(n2):
    m.append(n2[j])
    j+=1

# %%
def merge(n1,n2):
    m=[]
    i=j=0
    while i<len(n1) and j<len(n2):
        if n1[i]<=n2[j]:
            m.append(n1[i])
            i+=1
        else:
            m.append(n2[j])
            j+=1
    while i<len(n1):
        m.append(n1[i])
        i+=1
    while j<len(n2):
        m.append(n2[j])
        j+=1
    return m

# %%
merge([12,23],[45,56,0])
# Out:
# [12, 23, 45, 56, 0]

# %%
class a:
    def value(self,x,n):
        return pow(x,n)

# %%
value(2,-1)
# Out:
# 0.5

# %%
def number(num:list):
 if not isinstance(num,list):
     raise TypeError("input must be list")
 for i in range(len(num)-1):
     if num[i]>num[i+1]:
         return False
 else:
       return True
if __name__=="__main__":
    try:
        num=[12,45,56,67,78]
        result=number(num)
        print(result)
    except TypeError as error:
        print(error)
    except Exception as e:
        print(e)
# Out:
# True

# %%
number([12,23,34,45,10])
# Out:
# False

# %%
l1=[12,23,34,45]
l2=[34,45,67]
merge=[]
i=j=0
while i<len(l1) and j<len(l2):
    if l1[i]<=l2[j]:
        merge.append(l1[i])
        i+=1
    else:
        merge.append(l2[j])
        j+=1
while i<len(l1):
    merge.append(l1[i])
    i+=1
while j<len(l2):
    merge.append(l2[j])
    j+=1

print(merge)
# Out:
# [12, 23, 34, 34, 45, 45, 67]

# %%
def pow1(x,n):
    res=1
    for i in range(abs(n)):
        res*=x
    if n<0:
            return 1/res
    return res

# %%
pow1(2,-2)
# Out:
# 0.25
